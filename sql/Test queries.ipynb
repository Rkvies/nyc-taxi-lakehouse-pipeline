# %%
# %sql
SELECT * FROM workspace.bronze.trips_raw LIMIT 20;

# %%
# %sql
SELECT COUNT(*) FROM workspace.silver.trips_clean;

# %%
# %sql
SELECT * FROM workspace.gold.fact_trips LIMIT 20;

# %%
# %sql
SELECT * FROM workspace.monitoring.dq_check_log ORDER BY run_at DESC;
